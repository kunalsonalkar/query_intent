# %% [markdown]
# <a href="https://colab.research.google.com/github/kunalsonalkar/query_intent/blob/main/transformer_based_label_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset_url = "https://git.io/nlp-with-transformers"
df_issues = pd.read_json(dataset_url, lines = True)
df_issues.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/huggingface/trans...
# 1  https://api.github.com/repos/huggingface/trans...
# 2  https://api.github.com/repos/huggingface/trans...
# 3  https://api.github.com/repos/huggingface/trans...
# 4  https://api.github.com/repos/huggingface/trans...
#
#                                       repository_url  \
# 0  https://api.github.com/repos/huggingface/trans...
# 1  https://api.github.com/repos/huggingface/trans...
# 2  https://api.github.com/repos/huggingface/trans...
# 3  https://api.github.com/repos/huggingface/trans...
# 4  https://api.github.com/repos/huggingface/trans...
#
#                                           labels_url  \
# 0  https://api.github.com/repos/huggingface/trans...
# 1  https://api.github.com/repos/huggingface/trans...
# 2  https://api.github.com/repos/huggingface/trans...
# 3  https://api.github.com/repos/huggingface/trans...
# ...

# %%
cols = ["url","id","title","user","labels","state","created_at","body"]
df_issues.loc[2, cols].to_frame()
# Out:
#                                                             2
# url         https://api.github.com/repos/huggingface/trans...
# id                                                  849529761
# title       [DeepSpeed] ZeRO stage 3 integration: getting ...
# user        {'login': 'stas00', 'id': 10676103, 'node_id':...
# labels      [{'id': 2659267025, 'node_id': 'MDU6TGFiZWwyNj...
# state                                                    open
# created_at                                2021-04-02 23:40:42
# body        **[This is not yet alive, preparing for the re...

# %%
# Getting only the names of labels
df_issues['labels'] = (df_issues["labels"].apply(lambda x: [meta['name'] for meta in x]))

# %%
df_issues[["labels"]]
# Out:
#            labels
# 0              []
# 1              []
# 2     [DeepSpeed]
# 3              []
# 4              []
# ...           ...
# 9925           []
# 9926           []
# 9927           []
# 9928           []
# 9929    [wontfix]
#
# [9930 rows x 1 columns]

# %%
df_issues["labels"].apply(lambda x: len(x)).value_counts().to_frame().T
# Out:
# labels     0     1    2    3   4  5
# count   6440  3057  305  100  25  3
